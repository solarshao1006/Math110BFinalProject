# %% [markdown]
# <a href="https://colab.research.google.com/github/solarshao1006/Math110BFinalProject/blob/main/Final%20Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Compression with Constraints: Steganography
#
# The natural images are compressible, usually a full size image of several megabytes can be reduced to kilobytes level easily without lossing too much important information. Such property has been used widely to denoising, deblur, etc. techniques.
#
# The [``steganography``](https://en.wikipedia.org/wiki/Steganography) is a topic lying in the cryptography. It is concealing a file, message, image, or video within another file, message, image, or video.
#
# The advantage of steganography over cryptography alone is that the intended secret message ***does not attract attention to itself as an object of scrutiny***. Plainly visible encrypted messages, no matter how unbreakable they are, arouse interest and may in themselves be incriminating in countries in which encryption is illegal.
#
# Whereas cryptography is the practice of protecting the contents of a message alone, steganography is concerned both with concealing the fact that a secret message is being sent and its contents.
#
# Steganography includes the concealment of information within computer files. In digital steganography, electronic communications may include steganographic coding inside of a transport layer, such as a document file, image file, program or protocol. Media files are ideal for steganographic transmission because of their large size. For example, a sender might start with an innocuous image file and adjust the color of every hundredth pixel to correspond to a letter in the alphabet. The change is so subtle that someone who is not specifically looking for it is unlikely to notice the change.
#
# In this project, we deal with a special case: stegranography with images only. So unlike many practical scenes, for instance, encrypt text, document in images, this task might not be able to produce perfect recovery of information.

# %% [markdown]
# ## Purpose of the project
#
# The project is not meant to create super powerful technique to conceal information, it is more concerned to get used to imaging processing libraries and optimization techniques. On the other hand, it also provides a challenge to think about how to detect the ``steganographic`` images without the original images.

# %% [markdown]
# ## Mathematical aspects
#
# The stegranography has two important components: encryption and decryption.
#
# Suppose you have an original image and a secret image.
#
#
# 1.   Encryption: As a sender, your task is to make the original image and secret image merge into one image. The purpose is two fold. Firstly, your outcome must be an image, if this image stays far away from the original image, then it will attract other people's attention. That will count as a failure. Secondly, your outcome image must also convey the information of the secret image. It is not that simple, since any blending of information will change each other. The problem is how much we can afford.
# 2.   Decryption: After the encryption part, your outcome image will have two parts of information coming from original image and the secret image. As the receiver, your task will be inverting the encryption process, to recover the secret image as much as possible (Caution,  the receiver do not care about original image).
#
# If we mathematically represent such process, let $x$ be the original image, $y$ is the secret image, then $z = E(x, y)$ is the encrypted image, $E$ is the encryption function. You will try to minimize
# $$\|z - x\|$$
# The above norm is in certain sense, we will discuss that later. However, above minimization will subject to another constraint, which is the decryption function $D$ can recover sufficient information of the secret image. That is
# $$\|D(z) - y\|$$
# should be as small as possible.
#
# It is possible to construct a unified objective function:
# $$\min_{E, D} \|x - E(x,y)\| + \gamma \|y - D(z)\|$$
# where $E$ and $D$ are the parameters to find. $\gamma$ is a parameter chosen at your choice.
#
# Of course, there are other constraints from the images, because images are pixels, each pixel contains 3 channels: R,G,B, each one is a 8-bit integer, goes from 0 to 255. If the image has 4 channels RGBA, then it will provide more information. Therefore above optimization problem also has constraints that $E(x,y)$ and $D(z)$ must be images.

# %% [markdown]
# ## Algorithm 101, LSB
#
# The LSB is called least significant bits, which means you will replace the least significant bits of the original image with the secret image's most significant bits. This method will kill some information from both images, but the performance seems OK for general cases.
#
# Here are a few references on this simple algorithm:
#
# 0.   https://towardsdatascience.com/steganography-hiding-an-image-inside-another-77ca66b2acb1, the code is [here](https://github.com/kelvins/steganography)
# 1.   https://github.com/RobinDavid/LSB-Steganography
# 2.   https://pdfs.semanticscholar.org/3dce/b6307cee042b687b7f377ec1d5de91ce20b0.pdf
# 3.   https://hackernoon.com/simple-image-steganography-in-python-18c7b534854f
#
# The basic idea is (suppose you have a code to turn int8 into binary string),  inside each channel, say R, your original image's pixel, say represented as ``1001,0011``, and your secret image's that pixel is ``1110,1101``, then replace the last 4 bits in original image's pixel with the first 4 bits of secret image's corresponding pixel, the resulting number will be ``1001,1110``. In this way, the change in the original image could be small (on average).  There are other ways to alter the LSB, like treating the secret image as a binary string , and evenly distribute to each pixel. ***In our case, for simplicity, we only consider the images with the same size.***

# %% [markdown]
# ## Shortcomings
#
# The shortcomings of algorithms/methods are mainly on the detection, which is, we can easily detect your outcome image is not feeling right.
#
# In practice, if you look at the altered image, say from LSB, you do not feel anything. But the LSB has a very obvious drawback: it alters the last bit, which may distory the statistics of the last bit. In theory, the last bit 0 and 1 should obey certain heuristic distribution in the image, but now it will be changed.
#
# The detection code is here: https://github.com/b3dk7/StegExpose
#
# In https://dl.acm.org/citation.cfm?id=1929317, the paper introduced the method to preserve the statistics.
#
# In https://pdfs.semanticscholar.org/80a5/fcbeda7697d9641bc80460593c2f8f305a65.pdf, it introduced the detection of LSB.
#
#
# In http://futuremedia.szu.edu.cn/assets/files/CF_What%20makes%20the%20stego%20imageundetectable.pdf, the authors considered choosing the best original image to hide the given secret image
#
# Again,  currently, we are not supposed to consider this far, but it will be a future work if you find this interesting.

# %% [markdown]
# ## Other ways
#
# The review paper (maybe old) is found here: https://www.sciencedirect.com/science/article/pii/B9780123855107000023
#
# (some other reviews are found: [here](https://pdfs.semanticscholar.org/57a1/d15dcbf946f093a59db55f8828699fef7826.pdf) and [here](https://www.cscjournals.org/manuscript/Journals/IJCSS/Volume6/Issue3/IJCSS-670.pdf))
#
#
# 1.   https://arxiv.org/pdf/1606.05294.pdf. In this paper, it introduces the method to use NN to replace (learn) the LSB process.
# 2.   https://papers.nips.cc/paper/6802-hiding-images-in-plain-sight-deep-steganography.pdf, it introduced a NN to  approximate $D$ and $E$.
# 3. http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.178.7157&rep=rep1&type=pdf, it uses the DCT (discrete-cosine-transform) and LSB.
# 4. https://arxiv.org/pdf/1806.06357.pdf and  [code](https://github.com/adamcavendish/Deep-Image-Steganography)
# 5. https://ieeexplore.ieee.org/document/8403208/all-figures
# 6. https://eccv2018.org/openaccess/content_ECCV_2018/papers/Jiren_Zhu_HiDDeN_Hiding_Data_ECCV_2018_paper.pdf
# 7. https://arxiv.org/pdf/1904.01444.pdf
# 8. https://link.springer.com/article/10.1007/s00521-014-1702-1

# %% [markdown]
# ## First task
# Implement LSB, the images (orignal and secret) are of the same sizes. If you do not want to implement any, at least go through the code  [here](https://github.com/kelvins/steganography).

# %%
! mkdir ~/.kaggle

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets download gaz3ll3/optimization-ii-project-3
# Out:
# Downloading optimization-ii-project-3.zip to /content
#  96% 262M/274M [00:01<00:00, 164MB/s]
# 100% 274M/274M [00:01<00:00, 153MB/s]

# %%
! unzip 'optimization-ii-project-3.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating:
#   inflating: data/Opencountry/land228.jpg
#   inflating: data/Opencountry/land233.jpg
#   inflating: data/Opencountry/land238.jpg
#   inflating: data/Opencountry/land239.jpg
#   inflating: data/Opencountry/land269.jpg
#   inflating: data/Opencountry/land271.jpg
#   inflating: data/Opencountry/land276.jpg
#   inflating: data/Opencountry/land285.jpg
#   inflating: data/Opencountry/land290.jpg
#   inflating: data/Opencountry/land291.jpg
#   inflating: data/Opencountry/land295.jpg
#   inflating: data/Opencountry/land297.jpg
#   inflating: data/Opencountry/land298.jpg
#   inflating: data/Opencountry/land299.jpg
#   inflating: data/Opencountry/land342.jpg
#   inflating: data/Opencountry/land345.jpg
#   inflating: data/Opencountry/land348.jpg
#   inflating: data/Opencountry/land350.jpg
#   inflating: data/Opencountry/land351.jpg
#   inflating: data/Opencountry/land352.jpg
#   inflating: data/Opencountry/land353.jpg
#   inflating: data/Opencountry/land355.jpg
#   inflating: data/Opencountry/land358.jpg
#   inflating: data/Opencountry/land359.jpg
#   inflating: data/Opencountry/land364.jpg
#   inflating: data/Opencountry/land381.jpg
#   inflating: data/Opencountry/land388.jpg
#   inflating: data/Opencountry/land406.jpg
#   inflating: data/Opencountry/land41.jpg
#   inflating: data/Opencountry/land412.jpg
#   inflating: data/Opencountry/land416.jpg
#   inflating: data/Opencountry/land42.jpg
#   inflating: data/Opencountry/land431.jpg
#   inflating: data/Opencountry/land433.jpg
#   inflating: data/Opencountry/land443.jpg
#   inflating: data/Opencountry/land472.jpg
#   inflating: data/Opencountry/land48.jpg
#   inflating: data/Opencountry/land493.jpg
#   inflating: data/Opencountry/land494.jpg
#   inflating: data/Opencountry/land500.jpg
#   inflating: data/Opencountry/land501.jpg
#   inflating: data/Opencountry/land505.jpg
#   inflating: data/Opencountry/land507.jpg
#   inflating: data/Opencountry/land51.jpg
#   inflating: data/Opencountry/land513.jpg
#   inflating: data/Opencountry/land514.jpg
#   inflating: data/Opencountry/land515.jpg
#   inflating: data/Opencountry/land516.jpg
#   inflating: data/Opencountry/land520.jpg
#   inflating: data/Opencountry/land525.jpg
#   inflating: data/Opencountry/land526.jpg
#   inflating: data/Opencountry/land534.jpg
#   inflating: data/Opencountry/land540.jpg
#   inflating: data/Opencountry/land545.jpg
#   inflating: data/Opencountry/land549.jpg
#   inflating: data/Opencountry/land550.jpg
#   inflating: data/Opencountry/land555.jpg
#   inflating: data/Opencountry/land556.jpg
#   inflating: data/Opencountry/land557.jpg
#   inflating: data/Opencountry/land560.jpg
#   inflating: data/Opencountry/land564.jpg
#   inflating: data/Opencountry/land565.jpg
#   inflating: data/Opencountry/land572.jpg
#   inflating: data/Opencountry/land573.jpg
#   inflating: data/Opencountry/land575.jpg
#   inflating: data/Opencountry/land577.jpg
#   inflating: data/Opencountry/land588.jpg
#   inflating: data/Opencountry/land60.jpg
#   inflating: data/Opencountry/land600.jpg
#   inflating: data/Opencountry/land604.jpg
#   inflating: data/Opencountry/land605.jpg
#   inflating: data/Opencountry/land606.jpg
#   inflating: data/Opencountry/land61.jpg
#   inflating: data/Opencountry/land616.jpg
#   inflating: data/Opencountry/land617.jpg
#   inflating: data/Opencountry/land618.jpg
#   inflating: data/Opencountry/land625.jpg
#   inflating: data/Opencountry/land631.jpg
#   inflating: data/Opencountry/land638.jpg
#   inflating: data/Opencountry/land639.jpg
#   inflating: data/Opencountry/land640.jpg
#   inflating: data/Opencountry/land643.jpg
#   inflating: data/Opencountry/land645.jpg
#   inflating: data/Opencountry/land651.jpg
#   inflating: data/Opencountry/land652.jpg
#   inflating: data/Opencountry/land653.jpg
#   inflating: data/Opencountry/land655.jpg
#   inflating: data/Opencountry/land656.jpg
#   inflating: data/Opencountry/land657.jpg
#   inflating: data/Opencountry/land658.jpg
#   inflating: data/Opencountry/land659.jpg
#   inflating: data/Opencountry/land660.jpg
#   inflating: data/Opencountry/land661.jpg
#   inflating: data/Opencountry/land662.jpg
#   inflating: data/Opencountry/land663.jpg
#   inflating: data/Opencountry/land665.jpg
#   inflating: data/Opencountry/land666.jpg
#   inflating: data/Opencountry/land669.jpg
#   inflating: data/Opencountry/land68.jpg
#   inflating: data/Opencountry/land681.jpg
#   inflating: data/Opencountry/land684.jpg
#   inflating: data/Opencountry/land687.jpg
#   inflating: data/Opencountry/land688.jpg
#   inflating: data/Opencountry/land689.jpg
#   inflating: data/Opencountry/land690.jpg
#   inflating: data/Opencountry/land691.jpg
#   inflating: data/Opencountry/land692.jpg
#   inflating: data/Opencountry/land693.jpg
#   inflating: data/Opencountry/land694.jpg
#   inflating: data/Opencountry/land701.jpg
#   inflating: data/Opencountry/land703.jpg
#   inflating: data/Opencountry/land704.jpg
#   inflating: data/Opencountry/land709.jpg
#   inflating: data/Opencountry/land731.jpg
#   inflating: data/Opencountry/land732.jpg
#   inflating: data/Opencountry/land745.jpg
#   inflating: data/Opencountry/land764.jpg
#   inflating: data/Opencountry/land793.jpg
#   inflating: data/Opencountry/land797.jpg
#   inflating: data/Opencountry/land80.jpg
#   inflating: data/Opencountry/land817.jpg
#   inflating: data/Opencountry/land823.jpg
#   inflating: data/Opencountry/land825.jpg
#   inflating: data/Opencountry/land829.jpg
#   inflating: data/Opencountry/land833.jpg
#   inflating: data/Opencountry/land835.jpg
#   inflating: data/Opencountry/land87.jpg
#   inflating: data/Opencountry/land891.jpg
#   inflating: data/Opencountry/land903.jpg
#   inflating: data/Opencountry/land905.jpg
#   inflating: data/Opencountry/land911.jpg
#   inflating: data/Opencountry/land918.jpg
#   inflating: data/Opencountry/land923.jpg
#   inflating: data/Opencountry/land947.jpg
#   inflating: data/Opencountry/land952.jpg
#   inflating: data/Opencountry/land956.jpg
#   inflating: data/Opencountry/land957.jpg
#   inflating: data/Opencountry/land964.jpg
#   inflating: data/Opencountry/land965.jpg
#   inflating: data/Opencountry/moun17.jpg
#   inflating: data/Opencountry/moun21.jpg
#   inflating: data/Opencountry/moun36.jpg
#   inflating: data/Opencountry/moun39.jpg
#   inflating: data/Opencountry/moun8.jpg
#   inflating: data/Opencountry/n18000.jpg
#   inflating: data/Opencountry/n18002.jpg
#   inflating: data/Opencountry/n18003.jpg
#   inflating: data/Opencountry/n18011.jpg
#   inflating: data/Opencountry/n18012.jpg
#   inflating: data/Opencountry/n18026.jpg
#   inflating: data/Opencountry/n18041.jpg
#   inflating: data/Opencountry/n18053.jpg
#   inflating: data/Opencountry/n18054.jpg
#   inflating: data/Opencountry/n18073.jpg
#   inflating: data/Opencountry/n18077.jpg
#   inflating: data/Opencountry/n18080.jpg
#   inflating: data/Opencountry/n199000.jpg
#   inflating: data/Opencountry/n213027.jpg
#   inflating: data/Opencountry/n213045.jpg
#   inflating: data/Opencountry/n213059.jpg
#   inflating: data/Opencountry/n213060.jpg
#   inflating: data/Opencountry/n213061.jpg
#   inflating: data/Opencountry/n213062.jpg
#   inflating: data/Opencountry/n251011.jpg
#   inflating: data/Opencountry/n251015.jpg
#   inflating: data/Opencountry/n251016.jpg
#   inflating: data/Opencountry/n266024.jpg
#   inflating: data/Opencountry/n291048.jpg
#   inflating: data/Opencountry/n291050.jpg
#   inflating: data/Opencountry/n291051.jpg
#   inflating: data/Opencountry/n291054.jpg
#   inflating: data/Opencountry/n291056.jpg
#   inflating: data/Opencountry/n291058.jpg
#   inflating: data/Opencountry/n291082.jpg
#   inflating: data/Opencountry/n291085.jpg
#   inflating: data/Opencountry/n295006.jpg
#   inflating: data/Opencountry/n295046.jpg
#   inflating: data/Opencountry/n295071.jpg
#   inflating: data/Opencountry/n295072.jpg
#   inflating: data/Opencountry/n347020.jpg
#   inflating: data/Opencountry/n371052.jpg
#   inflating: data/Opencountry/n371053.jpg
#   inflating: data/Opencountry/n371054.jpg
#   inflating: data/Opencountry/n371057.jpg
#   inflating: data/Opencountry/n371061.jpg
#   inflating: data/Opencountry/n371070.jpg
#   inflating: data/Opencountry/n490003.jpg
#   inflating: data/Opencountry/n490067.jpg
#   inflating: data/Opencountry/n490070.jpg
#   inflating: data/Opencountry/n676082.jpg
#   inflating: data/Opencountry/n676095.jpg
#   inflating: data/Opencountry/nat1002.jpg
#   inflating: data/Opencountry/nat1010.jpg
#   inflating: data/Opencountry/nat1026.jpg
#   inflating: data/Opencountry/nat1034.jpg
#   inflating: data/Opencountry/nat1078.jpg
#   inflating: data/Opencountry/nat1105.jpg
#   inflating: data/Opencountry/nat1111.jpg
#   inflating: data/Opencountry/nat1113.jpg
#   inflating: data/Opencountry/nat1117.jpg
#   inflating: data/Opencountry/nat1118.jpg
#   inflating: data/Opencountry/nat1121.jpg
#   inflating: data/Opencountry/nat1122.jpg
#   inflating: data/Opencountry/nat1145.jpg
#   inflating: data/Opencountry/nat1183.jpg
#   inflating: data/Opencountry/nat125.jpg
#   inflating: data/Opencountry/nat1263.jpg
#   inflating: data/Opencountry/nat150.jpg
#   inflating: data/Opencountry/nat164.jpg
#   inflating: data/Opencountry/nat173.jpg
#   inflating: data/Opencountry/nat190.jpg
#   inflating: data/Opencountry/nat355.jpg
#   inflating: data/Opencountry/nat410.jpg
#   inflating: data/Opencountry/nat423.jpg
#   inflating: data/Opencountry/nat446.jpg
#   inflating: data/Opencountry/nat455.jpg
#   inflating: data/Opencountry/nat457.jpg
#   inflating: data/Opencountry/nat458.jpg
#   inflating: data/Opencountry/nat499.jpg
#   inflating: data/Opencountry/nat502.jpg
#   inflating: data/Opencountry/nat511.jpg
#   inflating: data/Opencountry/nat524.jpg
#   inflating: data/Opencountry/nat582.jpg
#   inflating: data/Opencountry/nat589.jpg
#   inflating: data/Opencountry/nat599.jpg
#   inflating: data/Opencountry/nat609.jpg
#   inflating: data/Opencountry/nat615.jpg
#   inflating: data/Opencountry/nat618.jpg
#   inflating: data/Opencountry/nat626.jpg
#   inflating: data/Opencountry/nat629.jpg
#   inflating: data/Opencountry/nat654.jpg
#   inflating: data/Opencountry/nat678.jpg
#   inflating: data/Opencountry/nat718.jpg
#   inflating: data/Opencountry/nat724.jpg
#   inflating: data/Opencountry/nat731.jpg
#   inflating: data/Opencountry/nat733.jpg
#   inflating: data/Opencountry/nat748.jpg
#   inflating: data/Opencountry/nat750.jpg
#   inflating: data/Opencountry/nat780.jpg
#   inflating: data/Opencountry/nat8.jpg
#   inflating: data/Opencountry/nat802.jpg
#   inflating: data/Opencountry/nat811.jpg
#   inflating: data/Opencountry/nat822.jpg
#   inflating: data/Opencountry/nat823.jpg
#   inflating: data/Opencountry/nat834.jpg
#   inflating: data/Opencountry/nat873.jpg
#   inflating: data/Opencountry/nat874.jpg
#   inflating: data/Opencountry/nat896.jpg
#   inflating: data/Opencountry/nat918.jpg
#   inflating: data/Opencountry/nat920.jpg
#   inflating: data/Opencountry/nat932.jpg
#   inflating: data/Opencountry/nat942.jpg
#   inflating: data/Opencountry/nat955.jpg
#   inflating: data/Opencountry/nat965.jpg
#   inflating: data/Opencountry/natu100.jpg
#   inflating: data/Opencountry/natu117.jpg
#   inflating: data/Opencountry/natu125.jpg
#   inflating: data/Opencountry/natu136.jpg
#   inflating: data/Opencountry/natu138.jpg
#   inflating: data/Opencountry/natu144.jpg
#   inflating: data/Opencountry/natu176.jpg
#   inflating: data/Opencountry/natu179.jpg
#   inflating: data/Opencountry/natu181.jpg
#   inflating: data/Opencountry/natu183.jpg
#   inflating: data/Opencountry/natu19.jpg
#   inflating: data/Opencountry/natu307.jpg
#   inflating: data/Opencountry/natu32.jpg
#   inflating: data/Opencountry/natu38.jpg
#   inflating: data/Opencountry/natu380.jpg
#   inflating: data/Opencountry/natu384.jpg
#   inflating: data/Opencountry/natu385.jpg
#   inflating: data/Opencountry/natu41.jpg
#   inflating: data/Opencountry/natu413.jpg
#   inflating: data/Opencountry/natu449.jpg
#   inflating: data/Opencountry/natu45.jpg
#   inflating: data/Opencountry/natu454.jpg
#   inflating: data/Opencountry/natu503.jpg
#   inflating: data/Opencountry/natu506.jpg
#   inflating: data/Opencountry/natu51.jpg
#   inflating: data/Opencountry/natu519.jpg
#   inflating: data/Opencountry/natu524.jpg
#   inflating: data/Opencountry/natu525.jpg
#   inflating: data/Opencountry/natu529.jpg
#   inflating: data/Opencountry/natu532.jpg
#   inflating: data/Opencountry/natu535.jpg
#   inflating: data/Opencountry/natu539.jpg
#   inflating: data/Opencountry/natu540.jpg
#   inflating: data/Opencountry/natu541.jpg
#   inflating: data/Opencountry/natu544.jpg
#   inflating: data/Opencountry/natu546.jpg
#   inflating: data/Opencountry/natu55.jpg
#   inflating: data/Opencountry/natu552.jpg
#   inflating: data/Opencountry/natu557.jpg
#   inflating: data/Opencountry/natu559.jpg
#   inflating: data/Opencountry/natu563.jpg
#   inflating: data/Opencountry/natu574.jpg
#   inflating: data/Opencountry/natu576.jpg
#   inflating: data/Opencountry/natu583.jpg
#   inflating: data/Opencountry/natu586.jpg
#   inflating: data/Opencountry/natu588.jpg
#   inflating: data/Opencountry/natu593.jpg
#   inflating: data/Opencountry/natu594.jpg
#   inflating: data/Opencountry/natu596.jpg
#   inflating: data/Opencountry/natu600.jpg
#   inflating: data/Opencountry/natu618.jpg
#   inflating: data/Opencountry/natu622.jpg
#   inflating: data/Opencountry/natu647.jpg
#   inflating: data/Opencountry/natu65.jpg
#   inflating: data/Opencountry/natu652.jpg
#   inflating: data/Opencountry/natu69.jpg
#   inflating: data/Opencountry/natu709.jpg
#   inflating: data/Opencountry/natu726.jpg
#   inflating: data/Opencountry/natu734.jpg
#   inflating: data/Opencountry/natu735.jpg
#   inflating: data/Opencountry/natu739.jpg
#   inflating: data/Opencountry/natu77.jpg
#   inflating: data/Opencountry/natu790.jpg
#   inflating: data/Opencountry/natu83.jpg
#   inflating: data/Opencountry/natu832.jpg
#   inflating: data/Opencountry/natu841.jpg
#   inflating: data/Opencountry/natu843.jpg
#   inflating: data/Opencountry/natu852.jpg
#   inflating: data/Opencountry/natu856.jpg
#   inflating: data/Opencountry/natu864.jpg
#   inflating: data/Opencountry/natu883.jpg
#   inflating: data/Opencountry/natu885.jpg
#   inflating: data/Opencountry/natu89.jpg
#   inflating: data/Opencountry/natu92.jpg
#   inflating: data/Opencountry/natu921.jpg
#   inflating: data/Opencountry/natu932.jpg
#   inflating: data/Opencountry/natu935.jpg
#   inflating: data/Opencountry/natu939.jpg
#   inflating: data/Opencountry/natu979.jpg
#   inflating: data/Opencountry/natu984.jpg
#   inflating: data/Opencountry/natu998.jpg
#   inflating: data/Opencountry/open11.jpg
#   inflating: data/Opencountry/open12.jpg
#   inflating: data/Opencountry/open30.jpg
#   inflating: data/Opencountry/open31.jpg
#   inflating: data/Opencountry/open35.jpg
#   inflating: data/Opencountry/open37.jpg
#   inflating: data/Opencountry/open38.jpg
#   inflating: data/Opencountry/open42.jpg
#   inflating: data/Opencountry/open47.jpg
#   inflating: data/Opencountry/open48.jpg
#   inflating: data/Opencountry/open52.jpg
#   inflating: data/Opencountry/open53.jpg
#   inflating: data/Opencountry/open55.jpg
#   inflating: data/Opencountry/open61.jpg
#   inflating: data/Opencountry/open7.jpg
#   inflating: data/Opencountry/osun12.jpg
#   inflating: data/Opencountry/sclos10.jpg
#   inflating: data/Opencountry/sclos18.jpg
#   inflating: data/Opencountry/sclos30.jpg
#   inflating: data/Opencountry/sopen10.jpg
#   inflating: data/Opencountry/sopen11.jpg
#   inflating: tallbuilding/urban1126.jpg
#   inflating: tallbuilding/urban1141.jpg
#   inflating: tallbuilding/urban1150.jpg
#   inflating: tallbuilding/urban1152.jpg
#   inflating: tallbuilding/urban1158.jpg
#   inflating: tallbuilding/urban1172.jpg
#   inflating: tallbuilding/urban1177.jpg
#   inflating: tallbuilding/urban1193.jpg
#   inflating: tallbuilding/urban1202.jpg
#   inflating: tallbuilding/urban1210.jpg
#   inflating: tallbuilding/urban15.jpg
#   inflating: tallbuilding/urban157.jpg
#   inflating: tallbuilding/urban158.jpg
#   inflating: tallbuilding/urban16.jpg
#   inflating: tallbuilding/urban166.jpg
#   inflating: tallbuilding/urban167.jpg
#   inflating: tallbuilding/urban171.jpg
#   inflating: tallbuilding/urban22.jpg
#   inflating: tallbuilding/urban24.jpg
#   inflating: tallbuilding/urban28.jpg
#   inflating: tallbuilding/urban3.jpg
#   inflating: tallbuilding/urban4.jpg
#   inflating: tallbuilding/urban445.jpg
#   inflating: tallbuilding/urban45.jpg
#   inflating: tallbuilding/urban596.jpg
#   inflating: tallbuilding/urban649.jpg
#   inflating: tallbuilding/urban693.jpg
#   inflating: tallbuilding/urban73.jpg
#   inflating: tallbuilding/urban732.jpg
#   inflating: tallbuilding/urban744.jpg
#   inflating: tallbuilding/urban745.jpg
#   inflating: tallbuilding/urban749.jpg
#   inflating: tallbuilding/urban780.jpg
#   inflating: tallbuilding/urban787.jpg
#   inflating: tallbuilding/urban828.jpg
#   inflating: tallbuilding/urban846.jpg
#   inflating: tallbuilding/urban979.jpg
#   inflating: tallbuilding/urban982.jpg
#   inflating: tallbuilding/urban983.jpg
#   inflating: tallbuilding/urban987.jpg
#   inflating: tallbuilding/urban989.jpg
#   inflating: tallbuilding/urban991.jpg

# %%
import os
os.listdir()
# Out:
# ['.config',
#  'highway',
#  'optimization-ii-project-3.zip',
#  'Opencountry',
#  'mountain',
#  'forest',
#  'street',
#  'data',
#  'coast',
#  'kaggle.json',
#  'tallbuilding',
#  'inside_city',
#  'sample_data']

# %%
from google.colab import files
from io import BytesIO
from IPython.display import Image, display

# %%
#Upload images
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2aae1d46-fe02-404f-ab6b-30da4ba23d1e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2aae1d46-fe02-404f-ab6b-30da4ba23d1e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
import os
#Check current directory
os.listdir()

# %%
import click
import PIL

class Steganography:

    @staticmethod
    def __int_to_bin(rgb):
        """Convert an integer tuple to a binary (string) tuple.
        :param rgb: An integer tuple (e.g. (220, 110, 96))
        :return: A string tuple (e.g. ("00101010", "11101011", "00010110"))
        """
        r, g, b = rgb
        return (f'{r:08b}',
                f'{g:08b}',
                f'{b:08b}')

    @staticmethod
    def __bin_to_int(rgb):
        """Convert a binary (string) tuple to an integer tuple.
        :param rgb: A string tuple (e.g. ("00101010", "11101011", "00010110"))
        :return: Return an int tuple (e.g. (220, 110, 96))
        """
        r, g, b = rgb
        return (int(r, 2),
                int(g, 2),
                int(b, 2))

    @staticmethod
    def __merge_rgb(rgb1, rgb2):
        """Merge two RGB tuples.
        :param rgb1: A string tuple (e.g. ("00101010", "11101011", "00010110"))
        :param rgb2: Another string tuple
        (e.g. ("00101010", "11101011", "00010110"))
        :return: An integer tuple with the two RGB values merged.
        """
        r1, g1, b1 = rgb1
        r2, g2, b2 = rgb2
        rgb = (r1[:4] + r2[:4],
               g1[:4] + g2[:4],
               b1[:4] + b2[:4])
        return rgb

    @staticmethod
    def merge(img1, img2):
        """Merge two images. The second one will be merged into the first one.
        :param img1: First image
        :param img2: Second image
        :return: A new merged image.
        """

        # Check the images dimensions
        if img2.size[0] > img1.size[0] or img2.size[1] > img1.size[1]:
            raise ValueError('Image 2 should not be larger than Image 1!')

        # Get the pixel map of the two images
        pixel_map1 = img1.load()
        pixel_map2 = img2.load()

        # Create a new image that will be outputted
        new_image = PIL.Image.new(img1.mode, img1.size)
        pixels_new = new_image.load()

        for i in range(img1.size[0]):
            for j in range(img1.size[1]):
                rgb1 = Steganography.__int_to_bin(pixel_map1[i, j])

                # Use a black pixel as default
                rgb2 = Steganography.__int_to_bin((0, 0, 0))

                # Check if the pixel map position is valid for the second image
                if i < img2.size[0] and j < img2.size[1]:
                    rgb2 = Steganography.__int_to_bin(pixel_map2[i, j])

                # Merge the two pixels and convert it to a integer tuple
                rgb = Steganography.__merge_rgb(rgb1, rgb2)

                pixels_new[i, j] = Steganography.__bin_to_int(rgb)

        return new_image

    @staticmethod
    def unmerge(img):
        """Unmerge an image.
        :param img: The input image.
        :return: The unmerged/extracted image.
        """

        # Load the pixel map
        pixel_map = img.load()

        # Create the new image and load the pixel map
        new_image = PIL.Image.new(img.mode, img.size)
        pixels_new = new_image.load()

        # Tuple used to store the image original size
        original_size = img.size

        for i in range(img.size[0]):
            for j in range(img.size[1]):
                # Get the RGB (as a string tuple) from the current pixel
                r, g, b = Steganography.__int_to_bin(pixel_map[i, j])

                # Extract the last 4 bits (corresponding to the hidden image)
                # Concatenate 4 zero bits because we are working with 8 bit
                rgb = (r[4:] + '0000',
                       g[4:] + '0000',
                       b[4:] + '0000')

                # Convert it to an integer tuple
                pixels_new[i, j] = Steganography.__bin_to_int(rgb)

                # If this is a 'valid' position, store it
                # as the last valid position
                if pixels_new[i, j] != (0, 0, 0):
                    original_size = (i + 1, j + 1)

        # Crop the image based on the 'valid' pixels
        new_image = new_image.crop((0, 0, original_size[0], original_size[1]))

        return new_image

def merge(img1, img2, output):
    merged_image = Steganography.merge(PIL.Image.open(img1), PIL.Image.open(img2))
    merged_image.save(output)

def unmerge(img, output):
    unmerged_image = Steganography.unmerge(PIL.Image.open(img))
    unmerged_image.save(output)

# %%
#Call the function directly instead of using the command line
merge('img1.jpg', 'img2.jpg', 'output_merge.png')
unmerge('output_merge.png', 'output_unmerge.png')

# %%
#Check the current directory list now, the outputs are in the directory
os.listdir()

# %%
#Visualization
display(Image('output_merge.png'))

# %%
#Visualization
display(Image('output_unmerge.png'))

# %% [markdown]
# ## Second task
# Try to use neural network to approximate $D$ and $E$, the parameters are up to you, the structure is up to you.  This paper provides a good insight: https://papers.nips.cc/paper/6802-hiding-images-in-plain-sight-deep-steganography.pdf,  an implementation is found here: https://github.com/fpingham/DeepSteg/blob/master/DeepSteganography.ipynb, https://github.com/Ankit-Dhankhar/deep-steg/blob/master/steg%20net.py, and https://github.com/mr3coi/deepsteg and https://github.com/alexandremuzio/deep-steg and https://github.com/harveyslash/Deep-Steganography....., a blog https://buzzrobot.com/hiding-images-using-ai-deep-steganography-b7726bd58b06
#
# For the network structure, you can borrow the idea from autoencoder for the $E$ part, in that paper, the authors claimed the $E$ part uses 5 layers of convolutional neural networks with 3x3, 4x4, 5x5 patches. The idea is only to approximate the mappings $D$ and $E$, the fully connected network should also work, but convolutional type is cheaper.
#
# A good way to combine DCT (discrete-cosine-transform) to reduce the information first on secret images (bypassing the prep network in the paper). References are easy to find by searching google with DCT keywords.

# %%
# Imports necessary libraries and modules
from itertools import islice
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch.autograd import Variable
from torch import utils
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import os 
import pickle
from PIL import Image
from torchvision import datasets, utils
import torchvision.transforms as transforms
from torchvision.transforms import ToPILImage
from random import shuffle
from IPython.display import Image
from google.colab import drive
import random
from collections import OrderedDict

# %%
os.listdir('data/highway')
# Out:
# ['a866041.jpg',
#  'gre40.jpg',
#  'art608.jpg',
#  'gre458.jpg',
#  'bost301.jpg',
#  'gre467.jpg',
#  'bost166.jpg',
#  'urb962.jpg',
#  'gre279.jpg',
#  'bost387.jpg',
#  'urb743.jpg',
#  'art820.jpg',
#  'gre239.jpg',
#  'a866042.jpg',
#  'bost173.jpg',
#  'art596.jpg',
#  'gre644.jpg',
#  'gre409.jpg',
#  'par23.jpg',
#  'gre662.jpg',
#  'bost180.jpg',
#  'bost403.jpg',
#  'art237.jpg',
#  'n480023.jpg',
#  'gre504.jpg',
#  'bost181.jpg',
#  'gre36.jpg',
#  'n480045.jpg',
#  'gre30.jpg',
#  'gre470.jpg',
#  'bost172.jpg',
#  'bost389.jpg',
#  'nat533.jpg',
#  'bost302.jpg',
#  'bost171.jpg',
#  'bost168.jpg',
#  'gre48.jpg',
#  'gre678.jpg',
#  'bost314.jpg',
#  'bost295.jpg',
#  'gre462.jpg',
#  'gre658.jpg',
#  'art558.jpg',
#  'gre413.jpg',
#  'art1204.jpg',
#  'bost331.jpg',
#  'n480036.jpg',
#  'land449.jpg',
#  'art1696.jpg',
#  'gre404.jpg',
#  'urb471.jpg',
#  'bost307.jpg',
#  'bost161.jpg',
#  'gre609.jpg',
#  'gre493.jpg',
#  'gre147.jpg',
#  'urb714.jpg',
#  'gre473.jpg',
#  'art563.jpg',
#  'bost160.jpg',
#  'urb713.jpg',
#  'land464.jpg',
#  'urb720.jpg',
#  'bost179.jpg',
#  'gre275.jpg',
#  'gre406.jpg',
#  'n480070.jpg',
#  'gre525.jpg',
#  'bost335.jpg',
#  'n480020.jpg',
#  'bost291.jpg',
#  'bost164.jpg',
#  'gre144.jpg',
#  'gre645.jpg',
#  'bost329.jpg',
#  'gre657.jpg',
#  'gre680.jpg',
#  'bost319.jpg',
#  'gre492.jpg',
#  'gre46.jpg',
#  'bost178.jpg',
#  'gre42.jpg',
#  'art255.jpg',
#  'gre684.jpg',
#  'bost292.jpg',
#  'bost397.jpg',
#  'gre403.jpg',
#  'nat542.jpg',
#  'urb784.jpg',
#  'bost312.jpg',
#  'gre400.jpg',
#  'bost322.jpg',
#  'gre411.jpg',
#  'bost157.jpg',
#  'nat546.jpg',
#  'bost152.jpg',
#  'bost334.jpg',
#  'gre650.jpg',
#  'gre45.jpg',
#  'bost393.jpg',
#  'bost186.jpg',
#  'art489.jpg',
#  'bost174.jpg',
#  'bost154.jpg',
#  'bost323.jpg',
#  'bost176.jpg',
#  'art568.jpg',
#  'bost147.jpg',
#  'bost313.jpg',
#  'bost315.jpg',
#  'bost394.jpg',
#  'gre37.jpg',
#  'bost155.jpg',
#  'nat550.jpg',
#  'bost325.jpg',
#  'gre149.jpg',
#  'gre479.jpg',
#  'bost169.jpg',
#  'gre530.jpg',
#  'gre41.jpg',
#  'gre155.jpg',
#  'bost321.jpg',
#  'a836030.jpg',
#  'nat526.jpg',
#  'bost398.jpg',
#  'bost163.jpg',
#  'bost306.jpg',
#  'gre408.jpg',
#  'art254.jpg',
#  'urb537.jpg',
#  'bost311.jpg',
#  'gre659.jpg',
#  'bost156.jpg',
#  'a866047.jpg',
#  'bost153.jpg',
#  'nat520.jpg',
#  'urb715.jpg',
#  'gre476.jpg',
#  'gre533.jpg',
#  'gre683.jpg',
#  'art1134.jpg',
#  'bost162.jpg',
#  'gre661.jpg',
#  'bost308.jpg',
#  'bost320.jpg',
#  'gre50.jpg',
#  'natu787.jpg',
#  'bost185.jpg',
#  'land409.jpg',
#  'urb681.jpg',
#  'bost151.jpg',
#  'bost332.jpg',
#  'gre414.jpg',
#  'art250.jpg',
#  'nat518.jpg',
#  'bost317.jpg',
#  'gre145.jpg',
#  'bost149.jpg',
#  'gre474.jpg',
#  'urb759.jpg',
#  'art773.jpg',
#  'bost318.jpg',
#  'bost296.jpg',
#  'bost326.jpg',
#  'gre537.jpg',
#  'gre426.jpg',
#  'bost159.jpg',
#  'art874.jpg',
#  'bost148.jpg',
#  'art580.jpg',
#  'gre140.jpg',
#  'gre651.jpg',
#  'gre541.jpg',
#  'gre53.jpg',
#  'bost170.jpg',
#  'gre410.jpg',
#  'bost310.jpg',
#  'art890.jpg',
#  'art1679.jpg',
#  'art576.jpg',
#  'bost304.jpg',
#  'bost336.jpg',
#  'gre646.jpg',
#  'gre402.jpg',
#  'bost183.jpg',
#  'gre656.jpg',
#  'art1674.jpg',
#  'art803.jpg',
#  'art1693.jpg',
#  'bost316.jpg',
#  'art579.jpg',
#  'bost392.jpg',
#  'bost298.jpg',
#  'bost167.jpg',
#  'bost184.jpg',
#  'gre407.jpg',
#  'bost165.jpg',
#  'gre466.jpg',
#  'gre58.jpg',
#  'gre481.jpg',
#  'gre459.jpg',
#  'gre420.jpg',
#  'urb754.jpg',
#  'gre538.jpg',
#  'gre35.jpg',
#  'gre472.jpg',
#  'urb744.jpg',
#  'Thumbs.db',
#  'gre277.jpg',
#  'n480001.jpg',
#  'urb710.jpg',
#  'bost290.jpg',
#  'natu778.jpg',
#  'gre491.jpg',
#  'gre536.jpg',
#  'gre141.jpg',
#  'gre415.jpg',
#  'urb716.jpg',
#  'bost294.jpg',
#  'art252.jpg',
#  'art238.jpg',
#  'gre485.jpg',
#  'gre478.jpg',
#  'gre125.jpg',
#  'bost395.jpg',
#  'bost402.jpg',
#  'gre52.jpg',
#  'gre480.jpg',
#  'gre475.jpg',
#  'bost300.jpg',
#  'art885.jpg',
#  'bost324.jpg',
#  'gre532.jpg',
#  'art813.jpg',
#  'bost182.jpg',
#  'bost175.jpg',
#  'gre153.jpg',
#  'art1673.jpg',
#  'bost303.jpg',
#  'gre685.jpg',
#  'bost374.jpg',
#  'bost309.jpg',
#  'bost297.jpg',
#  'bost158.jpg',
#  'nat543.jpg',
#  'bost330.jpg',
#  'art328.jpg',
#  'gre55.jpg',
#  'art336.jpg',
#  'bost150.jpg',
#  'bost305.jpg',
#  'gre484.jpg',
#  'bost177.jpg',
#  'bost293.jpg',
#  'land463.jpg',
#  'a866048.jpg',
#  'bost299.jpg',
#  'art1682.jpg',
#  'gre610.jpg',
#  'bost187.jpg',
#  'urb545.jpg']

# %%
def load_data():
  '''
  Load data into tensor format and add to a list.
  '''
  data_list = []
  folder_dir = 'data/highway'
  file_dirlist = os.listdir(folder_dir)
  for file_dir in file_dirlist:
    split = os.path.splitext(file_dir)
    if split[1] == '.jpg' or split[1] == '.png' or split[1] == '.jpeg':
      file_full_path = os.path.join(folder_dir, file_dir)
      image_tensor = torchvision.io.read_image(file_full_path)
      data_list.append(image_tensor.div(256))
  return data_list

# %%
def create_train_test_set():
  '''
  Create Train Set and Test Set; 80% of the data are randomly chosen as train set and the rest are test set.
  '''
  file_dir = load_data()
  random.shuffle(file_dir)
  train_set = file_dir[:int(0.8*len(file_dir))]
  test_set = file_dir[int(0.8*len(file_dir)):]
  return train_set, test_set

# %%
def separate_cover_secret(train_set, test_set):
  '''
  Separate cover and secret set from train set and test set. First half as cover set, second half as secret set. 
  '''
  train_set_cover = train_set[int(len(train_set) / 2):]
  train_set_secret = train_set[:int(len(train_set) / 2)]

  test_set_cover = test_set[int(len(test_set) / 2):]
  test_set_secret = test_set[:int(len(test_set) / 2)]
  return train_set_cover, train_set_secret, test_set_cover, test_set_secret

# %%
#Create Training Set and Test set, cover_set and secret set
train_set_, test_set_ = create_train_test_set()
train_set_cover, train_set_secret, test_set_cover, test_set_secret = separate_cover_secret(train_set_, test_set_)

# %%
class PrepNetwork(nn.Module):
    def __init__(self):
        super(PrepNetwork, self).__init__()
        self.initialP3 = nn.Sequential(OrderedDict([
          ('conv1', nn.Conv2d(1,50,kernel_size = 3, padding=1)),
          ('relu1', nn.ReLU()),
          ('conv2', nn.Conv2d(50,50,kernel_size = 3, padding=1)),
          ('relu2', nn.ReLU()),
          ('conv3', nn.Conv2d(50,50, kernel_size=3, padding=1)),
          ('relu3', nn.ReLU()),
          ('conv4', nn.Conv2d(50,50, kernel_size=3, padding=1)),
          ('relu4', nn.ReLU())
        ]))
        self.initialP4 = nn.Sequential(OrderedDict([
          ('conv5', nn.Conv2d(1,50,kernel_size = 4, padding=1)),
          ('relu5', nn.ReLU()),
          ('conv6', nn.Conv2d(50,50,kernel_size = 4, padding=2)),
          ('relu6', nn.ReLU()),
          ('conv7', nn.Conv2d(50,50, kernel_size=4, padding=1)),
          ('relu7', nn.ReLU()),
          ('conv8', nn.Conv2d(50,50, kernel_size=4, padding=2)),
          ('relu8', nn.ReLU())
        ]))
        self.initialP5 = nn.Sequential(OrderedDict([
          ('conv9', nn.Conv2d(1,50,kernel_size = 5, padding=2)),
          ('relu9', nn.ReLU()),
          ('conv10', nn.Conv2d(50,50,kernel_size = 5, padding=2)),
          ('relu10', nn.ReLU()),
          ('conv11', nn.Conv2d(50,50, kernel_size= 5, padding=2)),
          ('relu11', nn.ReLU()),
          ('conv12', nn.Conv2d(50,50, kernel_size=5, padding=2)),
          ('relu12', nn.ReLU())
        ]))
        self.finalP3 = nn.Sequential(OrderedDict([
          ('conv13', nn.Conv2d(150,50,kernel_size = 3, padding=1)),
          ('relu13', nn.ReLU())
        ]))
        self.finalP4 = nn.Sequential(OrderedDict([
          ('conv14', nn.Conv2d(150,50,kernel_size = 4, padding=1)),
          ('relu14', nn.ReLU()),
          ('conv15', nn.Conv2d(50, 50, kernel_size=4, padding=2)),
          ('relu15', nn.ReLU())
        ]))
        self.finalP5 = nn.Sequential(OrderedDict([
          ('conv16', nn.Conv2d(150,50, kernel_size = 5, padding=2)),
          ('relu16', nn.ReLU())
        ]))
        

    def forward(self, p):
        p1 = self.initialP3(p)
        p2 = self.initialP4(p)
        p3 = self.initialP5(p)
        mid = torch.cat((p1, p2, p3), 1)
        p4 = self.finalP3(mid)
        p5 = self.finalP4(mid)
        p6 = self.finalP5(mid)
        out = torch.cat((p4, p5, p6), 1)
        return out

# Hiding Network (5 conv layers)
class HidingNetwork(nn.Module):
    def __init__(self):
        super(HidingNetwork, self).__init__()
        self.initialH3 = nn.Sequential(
            nn.Conv2d(151, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialH4 = nn.Sequential(
            nn.Conv2d(151, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialH5 = nn.Sequential(
            nn.Conv2d(151, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalH3 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalH4 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalH5 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalH = nn.Sequential(
            nn.Conv2d(150, 3, kernel_size=1, padding=0))
        
    def forward(self, h):
        h1 = self.initialH3(h)
        h2 = self.initialH4(h)
        h3 = self.initialH5(h)
        mid = torch.cat((h1, h2, h3), 1)
        h4 = self.finalH3(mid)
        h5 = self.finalH4(mid)
        h6 = self.finalH5(mid)
        mid2 = torch.cat((h4, h5, h6), 1)
        out = self.finalH(mid2)
        out_noise = gaussian(out.data, 0, 0.1)
        return out, out_noise

# Reveal Network (2 conv layers)
class RevealNetwork(nn.Module):
    def __init__(self):
        super(RevealNetwork, self).__init__()
        self.initialR3 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialR4 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialR5 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalR3 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalR4 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalR5 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalR = nn.Sequential(
            nn.Conv2d(150, 3, kernel_size=1, padding=0))

    def forward(self, r):
        r1 = self.initialR3(r)
        r2 = self.initialR4(r)
        r3 = self.initialR5(r)
        mid = torch.cat((r1, r2, r3), 1)
        r4 = self.finalR3(mid)
        r5 = self.finalR4(mid)
        r6 = self.finalR5(mid)
        mid2 = torch.cat((r4, r5, r6), 1)
        out = self.finalR(mid2)
        return out

# Join three networks in one module
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.m1 = PrepNetwork()
        self.m2 = HidingNetwork()
        self.m3 = RevealNetwork()

    def forward(self, secret, cover):
        x_1 = self.m1(secret)
        mid = torch.cat((x_1, cover), 1)
        x_2, x_2_noise = self.m2(mid)
        x_3 = self.m3(x_2_noise)
        return x_2, x_3
model = nn.Sequential(OrderedDict([
          ('conv1', nn.Conv2d(1,20,5)),
          ('relu1', nn.ReLU()),
          ('conv2', nn.Conv2d(20,64,5)),
          ('relu2', nn.ReLU())
        ]))

# %%
# Creates net object
net = Net()

# %%
def customized_loss(S_prime, C_prime, S, C, B):
    ''' Calculates loss specified on the paper.'''
    loss_cover = torch.nn.functional.mse_loss(C_prime, C)
    loss_secret = torch.nn.functional.mse_loss(S_prime, S)
    loss_all = loss_cover + B * loss_secret
    return loss_all, loss_cover, loss_secret


def denormalize(image, std, mean):
    ''' Denormalizes a tensor of images.'''
    for t in range(3):
        image[t, :, :] = (image[t, :, :] * std[t]) + mean[t]
    return image


def gaussian(tensor, mean=0, stddev=0.1):
    '''Adds random noise to a tensor.'''
    noise = torch.nn.init.normal(torch.Tensor(tensor.size()), 0, 0.1)
    return Variable(tensor + noise)

# %%
net, mean_train_loss, loss_history = train_model(train_set_, train_set_secret, train_set_cover, beta, learning_rate, num_epochs)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: UserWarning: Using a target size (torch.Size([3, 1, 256, 256])) that is different to the input size (torch.Size([3, 3, 256, 256])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: Using a target size (torch.Size([3, 1, 256, 256])) that is different to the input size (torch.Size([3, 3, 256, 256])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   """
# Training: Batch 1/208. Loss of 0.7123, cover loss of 0.3277, secret loss of 0.3846
# Training: Batch 2/208. Loss of 0.6351, cover loss of 0.3398, secret loss of 0.2953
# Training: Batch 3/208. Loss of 0.6836, cover loss of 0.3579, secret loss of 0.3257
# Training: Batch 4/208. Loss of 0.4556, cover loss of 0.3286, secret loss of 0.1270
# Training: Batch 5/208. Loss of 0.3882, cover loss of 0.2037, secret loss of 0.1845
# Training: Batch 6/208. Loss of 0.4520, cover loss of 0.1192, secret loss of 0.3328
# Training: Batch 7/208. Loss of 0.5510, cover loss of 0.2785, secret loss of 0.2724
# Training: Batch 8/208. Loss of 0.4189, cover loss of 0.2639, secret loss of 0.1551
# Training: Batch 9/208. Loss of 0.3339, cover loss of 0.1051, secret loss of 0.2288
# Training: Batch 10/208. Loss of 0.5040, cover loss of 0.2553, secret loss of 0.2488
# Training: Batch 11/208. Loss of 0.5016, cover loss of 0.2538, secret loss of 0.2478
# Training: Batch 12/208. Loss of 0.3480, cover loss of 0.1019, secret loss of 0.2461
# Training: Batch 13/208. Loss of 0.2687, cover loss of 0.1254, secret loss of 0.1433
# Training: Batch 14/208. Loss of 0.3018, cover loss of 0.1340, secret loss of 0.1678
# Training: Batch 15/208. Loss of 0.1408, cover loss of 0.0811, secret loss of 0.0598
# Training: Batch 16/208. Loss of 0.1440, cover loss of 0.0849, secret loss of 0.0591
# Training: Batch 17/208. Loss of 0.2146, cover loss of 0.1156, secret loss of 0.0990
# Training: Batch 18/208. Loss of 0.0701, cover loss of 0.0308, secret loss of 0.0394
# Training: Batch 19/208. Loss of 0.0756, cover loss of 0.0292, secret loss of 0.0464
# Training: Batch 20/208. Loss of 0.0732, cover loss of 0.0391, secret loss of 0.0341
# Training: Batch 21/208. Loss of 0.1043, cover loss of 0.0652, secret loss of 0.0391
# Training: Batch 22/208. Loss of 0.2200, cover loss of 0.0568, secret loss of 0.1632
# Training: Batch 23/208. Loss of 0.1176, cover loss of 0.0392, secret loss of 0.0785
# Training: Batch 24/208. Loss of 0.0576, cover loss of 0.0316, secret loss of 0.0260
# Training: Batch 25/208. Loss of 0.1335, cover loss of 0.1173, secret loss of 0.0162
# Training: Batch 26/208. Loss of 0.0954, cover loss of 0.0441, secret loss of 0.0513
# Training: Batch 27/208. Loss of 0.0752, cover loss of 0.0339, secret loss of 0.0413
# Training: Batch 28/208. Loss of 0.1377, cover loss of 0.0598, secret loss of 0.0779
# Training: Batch 29/208. Loss of 0.0832, cover loss of 0.0269, secret loss of 0.0563
# Training: Batch 30/208. Loss of 0.0695, cover loss of 0.0506, secret loss of 0.0190
# Training: Batch 31/208. Loss of 0.0408, cover loss of 0.0188, secret loss of 0.0220
# Training: Batch 32/208. Loss of 0.0728, cover loss of 0.0343, secret loss of 0.0385
# Training: Batch 33/208. Loss of 0.0875, cover loss of 0.0246, secret loss of 0.0630
# Training: Batch 34/208. Loss of 0.1251, cover loss of 0.0926, secret loss of 0.0325

# %% [markdown]
# ## Optional Task
#
# What if you have two secret images to encrpt, what if there are more. Does LSB work? Does the NN work?

# %% [markdown]
# ## Data set
#
# https://www.kaggle.com/gaz3ll3/optimization-ii-project-3
#
# In order to efficiency, we only consider small pictures, 256x256. If you have problem dealing with 256x256, you can resize them to 128x128 or 64x64.  If you feel the images are too many, you can sample a portion from them as well.
#
# Training and Validation sets are chosen at random (say, 80% and 20%). Each input data will be two images from the training set.
#
# If you are more comfortable with other data sets, it is up to you. Say you can use https://tiny-imagenet.herokuapp.com/ for 64x64 small images.

# %% [markdown]
# ## Metric
#
# In your trainging process for $D$ and $E$, the norm to compare images is the RMSE (root mean squared error), the images are of dimension $N\times N\times 3$, BTW.

# %% [markdown]
# ## Your final result
#
#
# 1.   A writeup on your work, including performance, your work, issues, how do you solve the issues, etc.
# 2.   Test your codes (LSB and NN) against the data set http://r0k.us/graphics/kodak/, each image will be downsize to 256x256 or 128x128 or 64x64 if you trained an NN on smaller images. Report your result in your writeup.
# 3. Code, again, host on github. Submission will be a link.
# 4. If you also tried the optional task, please also report that in your writeup.

# %%
print('Good luck!')
